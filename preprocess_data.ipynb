# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("hack_ru.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df.head()
df = df.fillna(0)

# %%
df.describe()
# Out:
#        total_pack_size_ml_g  unit_pack_size_ml_g  price_per_100g_ml_dollars
# count          14847.000000         14847.000000               14847.000000
# mean             107.410317            94.914851                   4.766271
# std              133.960889            49.477564                   5.779356
# min                0.000000             0.300000                   0.010000
# 25%               75.000000            75.000000                   1.760000
# 50%               80.000000            75.000000                   3.440000
# 75%              120.000000           110.000000                   5.970000
# max            12825.000000          2218.010000                 252.000000

# %%
sns.pairplot(df)

# %%
sns.boxplot(x = df['total_pack_size_ml_g'], y = df['price_per_100g_ml_dollars'])

# %%
sns.distplot(df['total_pack_size_ml_g'])

# %%
sns.distplot(df['unit_pack_size_ml_g'])

# %%
df.corr()
# Out:
#                            total_pack_size_ml_g  unit_pack_size_ml_g  \
# total_pack_size_ml_g                   1.000000             0.406011
# unit_pack_size_ml_g                    0.406011             1.000000
# price_per_100g_ml_dollars             -0.152791            -0.290549
#
#                            price_per_100g_ml_dollars
# total_pack_size_ml_g                       -0.152791
# unit_pack_size_ml_g                        -0.290549
# price_per_100g_ml_dollars                   1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.plot(kind='box')

# %%
df.describe()
# Out:
#        total_pack_size_ml_g  unit_pack_size_ml_g  price_per_100g_ml_dollars
# count          14847.000000         14847.000000               14847.000000
# mean             107.410317            94.914851                   4.766271
# std              133.960889            49.477564                   5.779356
# min                0.000000             0.300000                   0.010000
# 25%               75.000000            75.000000                   1.760000
# 50%               80.000000            75.000000                   3.440000
# 75%              120.000000           110.000000                   5.970000
# max            12825.000000          2218.010000                 252.000000

# %%
df = df[df['price_per_100g_ml_dollars'] < 8]
# df = df[df['price_per_100g_ml_dollars'] > 1.5]
# df = df[df['total_pack_size_ml_g'] > 25] 
# df = df[df['total_pack_size_ml_g'] < 400] 
# df = df[df['unit_pack_size_ml_g'] > 20] 
df.describe()
# Out:
#        total_pack_size_ml_g  unit_pack_size_ml_g  price_per_100g_ml_dollars
# count          12777.000000         12777.000000               12777.000000
# mean             113.574876            99.150408                   3.277380
# std              143.035210            50.964667                   2.007228
# min                0.000000             4.000000                   0.010000
# 25%               75.000000            75.000000                   1.570000
# 50%               96.390000            88.000000                   2.920000
# 75%              125.000000           120.000000                   4.740000
# max            12825.000000          2218.010000                   7.990000

# %%
df.to_csv("stripped_data.csv")
